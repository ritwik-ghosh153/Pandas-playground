# %%
import numpy as np
import pandas as pd
import io
#import files
#from google.colab import files

# %%
#uploaded = files.upload()
df = pd.read_csv("/Users/ritwikghosh/Desktop/matches - matches.csv")
df
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
df.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
# Q1. Find the total number of matches played till now in IPL
print(len(df),"matches were played in the IPL")
# Out:
# 636 matches were played in the IPL

# %%
# Q2. Create a new dataframe from df which will have all the alternate rows and columns from df starting from 0
df_new=df.iloc[range(0,df.shape[0],2),range(0,df.shape[1],2)]
df_new
# Out:
#       id           city                        team1  \
# 0      1      Hyderabad          Sunrisers Hyderabad
# 2      3         Rajkot                Gujarat Lions
# 4      5      Bangalore  Royal Challengers Bangalore
# 6      7         Mumbai        Kolkata Knight Riders
# 8      9           Pune             Delhi Daredevils
# 10    11        Kolkata              Kings XI Punjab
# 12    13         Rajkot       Rising Pune Supergiant
# 14    15          Delhi             Delhi Daredevils
# 16    17      Bangalore       Rising Pune Supergiant
# 18    19      Hyderabad          Sunrisers Hyderabad
# 20    21      Hyderabad          Sunrisers Hyderabad
# 22    23        Kolkata        Kolkata Knight Riders
# 24    25           Pune          Sunrisers Hyderabad
# 26    27        Kolkata        Kolkata Knight Riders
# 28    29           Pune       Rising Pune Supergiant
# 30    31        Kolkata             Delhi Daredevils
# 32    33           Pune       Rising Pune Supergiant
# ...

# %%
# Q3. Find the number of matches played in Mumbai in the period of 2013 and 2017
print(len(df[(df["city"]=="Mumbai") & ((df["season"]<=2017)&(df["season"]>=2013))]),"matches were played in Mumbai from 2013 to 2017")
# Out:
# 38 matches were played in Mumbai from 2013 to 2017

# %%
# Q4. Find the number of matches where the margin of victory was greater than 30
print(len(df[df["win_by_runs"]>30]),"matches had a margin of victory of more than 30")
# Out:
# 103 matches had a margin of victory of more than 30

# %%
# Q5. What percent times KKR decides to bat after winning the toss

# %%
a=len(df[(df["toss_winner"]=="Kolkata Knight Riders") & (df["toss_decision"]=="bat")])
b=len(df[df["toss_winner"]=="Kolkata Knight Riders"])
print("KKR chose to bat ",round(a/b*100,2),"% times after winning the toss")
# Out:
# KKR chose to bat  38.46 % times after winning the toss
